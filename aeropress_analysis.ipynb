# %% [markdown]
# # AeroPress Analysis
#
# ## Introduction
# This notebook contains an analysis of my AeroPress brews over time. The brew data is recorded in YAML files which are then appended to a CSV file for analysis.
#
# ## Equipment
#
# All of the brews in this analysis were completed with the following equipment:
# * AeroPress coffee maker
# * Fellow Stagg EKG electric kettle
# * Baratza Sette 30 burr grinder
#
# ## Data Descriptions
#
# ### Timestamp
#
# * **`date`** [ yyyy-mm-dd ]  - *date of brewing*
# * **`time`** [ hh:mm AM/PM ] - *time of brewing*
#
# ### Brewing
# * **`drink_type`** [ coffee, espresso ] -  *type of drink brewed*
# * **`method`** [ standard, inverted ] -  *AeroPress brewing method*
# * **`filter`** [ AeroPress paper, Able Disk Standard, Able Disk Fine ] - *type of filter used*
# * **`coffee_type`** - *name of coffee used*
# * **`roast`** [ 1-5 ] - *roast of coffee used; 1 is light and 5 is dark*
# * **`grind_size`** [ 1-30 ] - *grind setting on Baratza Sette 30 grinder*
# * **`coffee_weight`** [ g ] - *weight in grams of ground coffee*
# * **`brew_water_weight`** [ g ] - *weight in grams of water used in brewing*
# * **`brew_water_temp`** [ F ] - *temperature in Fahrenheit of water used in brewing*
# * **`pour_duration`** [ sec ] - *duration in seconds of pour*
# * **`stir_start_time`** [ sec ] - *time elapsed at start of stir; default is 0*
# * **`stir_duration`** [ sec ] - *duration in seconds of stir*
# * **`push_start_time`** [ sec ] - *time elapsed at start of push*
# * **`push_duration`** [ sec ] - *duration in seconds of push*
# * **`overall_duration`** [ sec ] - *time elapsed between start of pour and end of push*
# * **`added_water_weight`** [ g ] - *weight in grams of water added after brewing*
# * **`added_water_temp`** [ F ] - *temperature in Fahrenheit of water added after brewing*
#
# ### Evaluation
#
# * **`extraction`** [ 1-5 ] - *extraction; 1 is under extracted and 5 is over extracted*
# * **`body`** [ thin, medium, full ] - *body of the coffee*
# * **`rating`** [ 1-10 ] - *personal rating of coffee*
# * **`notes`** - *any notes about brewing or results*
#
# ---

# %% [markdown]
# # Code

# %% [markdown]
# ## Setting up environment

# %%
# import libraries
import pandas as pd, numpy as np, csv, re, yaml, os

# edit Jupyter settings
# %config IPCompleter.greedy=True
# %config IPCompleter.use_jedi=False

# %%
# define data fields
data_fields = [
    'date',
    'time',
    'drink_type',
    'method',
    'filter',
    'coffee_type',
    'roast',
    'grind_size',
    'coffee_weight',
    'brew_water_weight',
    'brew_water_temp',
    'pour_duration',
    'stir_start_time',
    'stir_duration',
    'push_start_time',
    'push_duration',
    'overall_duration',
    'added_water_weight',
    'added_water_temp',
    'extraction',
    'body',
    'rating',
    'notes'
]

# %%
# create csv to store data
with open('aeropress_data.csv','w') as csv_file:
    csv_writer = csv.DictWriter(csv_file,fieldnames=data_fields)
    csv_writer.writeheader()

# %% [markdown]
# ## Recording data

# %%
# write brew data values to csv file and print results
def write_brew_record_to_csv(brew_record,csv_filepath='aeropress_data.csv'):
    with open(csv_filepath,'a') as csv_file:
        csv_writer = csv.DictWriter(csv_file,fieldnames=data_fields)
        csv_writer.writerow(brew_record)
        print("Wrote brew record to file:\n")
        for field, data in brew_record.items():
            print(f"\t{field.upper().replace('_',' ')}: {data}")
        print()

# %%
# convert 'mm:ss' string to seconds value
def minsec(mins):
    m,s = map(int,mins.split(':'))
    return (m*60) + s

# convert seconds value to 'mm:ss' string
def secmins(secs):
    m = secs//60
    s = secs % 60
    return f"{m}:{s:02}"

# %%
# read yaml brew record
def read_brew_record(yaml_filepath):
    with open(yaml_filepath,'r') as yaml_file:
        data = yaml.load(yaml_file)
        return data

# %%
def add_brew_record_to_csv(yaml_filepath,csv_filepath='aeropress_data'):
    brew_data = read_brew_record(yaml_filepath)
    write_brew_record_to_csv(brew_data)

# %%
brew_record_dir = './brew_records/'
brew_record_filepaths = [brew_record_dir+filepath for filepath in os.listdir(brew_record_dir) if not filepath.startswith('.')]

for filepath in brew_record_filepaths:
    add_brew_record_to_csv(filepath)
# Out:
# Wrote brew record to file:
#
# 	DATE: 2020-09-25
# 	TIME: 9:00 AM
# 	DRINK TYPE: coffee
# 	METHOD: inverted
# 	FILTER: AeroPress paper
# 	COFFEE TYPE: Revelator Coffee Misfit
# 	ROAST: 3
# 	GRIND SIZE: 26
# 	COFFEE WEIGHT: 24
# 	BREW WATER WEIGHT: 180
# 	BREW WATER TEMP: 186
# 	POUR DURATION: 15
# 	STIR START TIME: 15
# 	STIR DURATION: 15
# 	PUSH START TIME: 95
# 	PUSH DURATION: 40
# 	OVERALL DURATION: 135
# 	ADDED WATER WEIGHT: None
# 	ADDED WATER TEMP: None
# 	EXTRACTION: 2
# 	BODY: medium
# 	RATING: 6
# 	NOTES: None
#
# Wrote brew record to file:
#
# 	DATE: 2020-09-28
# 	TIME: 10:30 AM
# 	DRINK TYPE: espresso
# 	METHOD: inverted
# 	FILTER: AbleDisk Standard
# 	COFFEE TYPE: Revelator Coffee Misfit
# 	ROAST: 3
# 	GRIND SIZE: 26
# 	COFFEE WEIGHT: 20
# 	BREW WATER WEIGHT: 84
# 	BREW WATER TEMP: 186
# 	POUR DURATION: 15
# 	STIR START TIME: 15
# 	STIR DURATION: 30
# 	PUSH START TIME: 95
# 	PUSH DURATION: 10
# 	OVERALL DURATION: 105
# 	ADDED WATER WEIGHT: None
# 	ADDED WATER TEMP: None
# 	EXTRACTION: 4
# 	BODY: full
# 	RATING: 7
# 	NOTES: None
#
# Wrote brew record to file:
#
# 	DATE: 2020-09-25
# 	TIME: 01:50 PM
# 	DRINK TYPE: coffee
# 	METHOD: inverted
# 	FILTER: AeroPress paper
# 	COFFEE TYPE: Revelator Coffee Misfit
# 	ROAST: 3
# 	GRIND SIZE: 26
# 	COFFEE WEIGHT: 24
# 	BREW WATER WEIGHT: 180
# 	BREW WATER TEMP: 190
# 	POUR DURATION: 20
# 	STIR START TIME: 20
# 	STIR DURATION: 30
# 	PUSH START TIME: 95
# 	PUSH DURATION: 40
# 	OVERALL DURATION: 135
# 	ADDED WATER WEIGHT: 80
# 	ADDED WATER TEMP: 190
# 	EXTRACTION: 4
# 	BODY: medium
# 	RATING: 6
# 	NOTES: None
#
# Wrote brew record to file:
#
# 	DATE: 2020-09-29
# 	TIME: 8:30 AM
# 	DRINK TYPE: espresso
# 	METHOD: inverted
# 	FILTER: AbleDisk Fine
# 	COFFEE TYPE: Revelator Coffee Misfit
# 	ROAST: 3
# 	GRIND SIZE: 26
# 	COFFEE WEIGHT: 21
# 	BREW WATER WEIGHT: 84
# 	BREW WATER TEMP: 190
# 	POUR DURATION: 15
# 	STIR START TIME: 15
# 	STIR DURATION: 30
# 	PUSH START TIME: 120
# 	PUSH DURATION: 10
# 	OVERALL DURATION: 130
# 	ADDED WATER WEIGHT: None
# 	ADDED WATER TEMP: None
# 	EXTRACTION: 4
# 	BODY: medium
# 	RATING: 7
# 	NOTES: None
# /Users/BrandonBel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Analyzing data

# %%
brew_df = pd.read_csv('aeropress_data.csv')
brew_df
# Out:
#           date      time drink_type    method             filter  \
# 0   2020-09-25   9:00 AM     coffee  inverted    AeroPress paper
# 1   2020-09-28  10:30 AM   espresso  inverted  AbleDisk Standard
# 2   2020-09-25  01:50 PM     coffee  inverted    AeroPress paper
# 3   2020-09-29   8:30 AM   espresso  inverted      AbleDisk Fine
# 4   2020-09-25   9:00 AM     coffee  inverted    AeroPress paper
# 5   2020-09-28  10:30 AM   espresso  inverted  AbleDisk Standard
# 6   2020-09-25  01:50 PM     coffee  inverted    AeroPress paper
# 7   2020-09-29   8:30 AM   espresso  inverted      AbleDisk Fine
# 8   2020-09-25   9:00 AM     coffee  inverted    AeroPress paper
# 9   2020-09-28  10:30 AM   espresso  inverted  AbleDisk Standard
# 10  2020-09-25  01:50 PM     coffee  inverted    AeroPress paper
# 11  2020-09-29   8:30 AM   espresso  inverted      AbleDisk Fine
#
#                 coffee_type  roast  grind_size  coffee_weight  \
# 0   Revelator Coffee Misfit      3          26             24
# 1   Revelator Coffee Misfit      3          26             20
# 2   Revelator Coffee Misfit      3          26             24
# 3   Revelator Coffee Misfit      3          26             21
# 4   Revelator Coffee Misfit      3          26             24
# 5   Revelator Coffee Misfit      3          26             20
# 6   Revelator Coffee Misfit      3          26             24
# 7   Revelator Coffee Misfit      3          26             21
# 8   Revelator Coffee Misfit      3          26             24
# 9   Revelator Coffee Misfit      3          26             20
# 10  Revelator Coffee Misfit      3          26             24
# 11  Revelator Coffee Misfit      3          26             21
#
#     brew_water_weight  ...  stir_duration  push_start_time  push_duration  \
# 0                 180  ...             15               95             40
# 1                  84  ...             30               95             10
# 2                 180  ...             30               95             40
# 3                  84  ...             30              120             10
# 4                 180  ...             15               95             40
# 5                  84  ...             30               95             10
# 6                 180  ...             30               95             40
# 7                  84  ...             30              120             10
# 8                 180  ...             15               95             40
# 9                  84  ...             30               95             10
# 10                180  ...             30               95             40
# 11                 84  ...             30              120             10
#
#     overall_duration  added_water_weight  added_water_temp  extraction  \
# 0                135                 NaN               NaN           2
# 1                105                 NaN               NaN           4
# 2                135                80.0             190.0           4
# 3                130                 NaN               NaN           4
# 4                135                 NaN               NaN           2
# 5                105                 NaN               NaN           4
# 6                135                80.0             190.0           4
# 7                130                 NaN               NaN           4
# 8                135                 NaN               NaN           2
# 9                105                 NaN               NaN           4
# 10               135                80.0             190.0           4
# 11               130                 NaN               NaN           4
#
#       body  rating  notes
# 0   medium       6    NaN
# 1     full       7    NaN
# 2   medium       6    NaN
# 3   medium       7    NaN
# 4   medium       6    NaN
# 5     full       7    NaN
# 6   medium       6    NaN
# 7   medium       7    NaN
# 8   medium       6    NaN
# 9     full       7    NaN
# 10  medium       6    NaN
# 11  medium       7    NaN
#
# [12 rows x 23 columns]

# %% [markdown]
# ---
# # Old code

# %%
# # dictionary template for brew records
# brew_record_template = {
#     "date":,
#     "time":,
#     "method":,
#     "filter":,
#     "coffee_type":,
#     "roast":,
#     "grind_size":,
#     "coffee_weight":,
#     "brew_water_weight":,
#     "brew_water_temp":,
#     "pour_duration":,
#     "stir_start_time":,
#     "stir_duration":,
#     "push_start_time":,
#     "push_duration":,
#     "overall_duration":,
#     "added_water_weight":,
#     "added_water_temp":,
#     "extraction":,
#     "body":,
#     "rating":,
#     "notes": 
# }

# %%
# brew_record = {
#     "date":"2020-09-25",
#     "time":"09:00 AM",
#     "method":"inverted",
#     "filter":"AeroPress paper",
#     "coffee_type":"Revelator Coffee Misfit",
#     "roast":3,
#     "grind_size":26,
#     "coffee_weight":24,
#     "brew_water_weight":180,
#     "brew_water_temp":186,
#     "pour_duration":10,
#     "stir_start_time":5,
#     "stir_duration":15,
#     "push_start_time":minsec('1:35'),
#     "push_duration":40,
#     "overall_duration":minsec('2:15'),
#     "added_water_weight":0,
#     "added_water_temp":None,
#     "extraction":2,
#     "body":"medium",
#     "rating":6,
#     "notes":None 
# }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b8e2040c9957> in <module>
#      24 }
#      25
# ---> 26 write_brew_record(brew_record)
#
# NameError: name 'write_brew_record' is not defined
